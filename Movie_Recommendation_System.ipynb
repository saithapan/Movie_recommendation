# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Get the data

# %%
column_names = ['user_id','item_id','rating','timestamp']
df = pd.read_csv("C:\\Users\\sai thapan ragipani\\Desktop\\csv\\krish -projects\\Movie-Recommendation-system\\u.data",sep="\t",names=column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv("C:\\Users\\sai thapan ragipani\\Desktop\\csv\\krish -projects\\Movie-Recommendation-system\\Movie_Id_Titles")
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %% [markdown]
# Here i am combining the data and movie title with reference to item_id which common in both cases

# %%
df = pd.merge(df,movie_titles,on="item_id")
df.head()
# Out:
#    user_id  item_id  rating  timestamp           title_x           title_y  \
# 0        0       50       5  881250949  Star Wars (1977)  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)  Star Wars (1977)
#
#               title
# 0  Star Wars (1977)
# 1  Star Wars (1977)
# 2  Star Wars (1977)
# 3  Star Wars (1977)
# 4  Star Wars (1977)

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Import

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings
# Out:
#                                          rating
# title
# 'Til There Was You (1997)              2.333333
# 1-900 (1994)                           2.600000
# 101 Dalmatians (1996)                  2.908257
# 12 Angry Men (1957)                    4.344000
# 187 (1997)                             3.024390
# ...                                         ...
# Young Guns II (1990)                   2.772727
# Young Poisoner's Handbook, The (1995)  3.341463
# Zeus and Roxanne (1997)                2.166667
# unknown                                3.444444
# Á köldum klaka (Cold Fever) (1994)     3.000000
#
# [1664 rows x 1 columns]

# %%
ratings['number of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings
# Out:
#                                          rating  number of ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# Á köldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %% [markdown]
# Now a few histograms

# %%
plt.figure(figsize=(10,4))
ratings['number of ratings'].hist(bins=70)

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)

# %%
sns.jointplot(x='rating',y='number of ratings',data=ratings,alpha=0.5)

# %% [markdown]
# # Recommending similar movies

# %%
moviemat = pd.pivot_table(index="user_id",columns="title",values='rating',data=df)
moviemat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
ratings.sort_values('number of ratings',ascending=False).head(10)
# Out:
#                                  rating  number of ratings
# title
# Star Wars (1977)               4.359589                584
# Contact (1997)                 3.803536                509
# Fargo (1996)                   4.155512                508
# Return of the Jedi (1983)      4.007890                507
# Liar Liar (1997)               3.156701                485
# English Patient, The (1996)    3.656965                481
# Scream (1996)                  3.441423                478
# Toy Story (1995)               3.878319                452
# Air Force One (1997)           3.631090                431
# Independence Day (ID4) (1996)  3.438228                429

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %% [markdown]
# We can then usee corrwith() method to get correlations b/w two pandas series:

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)

# %% [markdown]
# Let's clean this by removing NaN values and using a DataSet instead of series

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=["correlation"])
corr_starwars.dropna(inplace=True)
corr_starwars
# Out:
#                                        correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns (1988)                         0.186377
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
#
# [1410 rows x 1 columns]

# %%
corr_starwars.sort_values('correlation',ascending=False).head(10)
# Out:
#                                                     correlation
# title
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Man of the Year (1995)                                      1.0
# Hollow Reed (1996)                                          1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Good Man in Africa, A (1994)                                1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corr_starwars =  corr_starwars.join(ratings['number of ratings'])
corr_starwars.head()
# Out:
#                            correlation  number of ratings
# title
# 'Til There Was You (1997)     0.872872                  9
# 1-900 (1994)                 -0.645497                  5
# 101 Dalmatians (1996)         0.211132                109
# 12 Angry Men (1957)           0.184289                125
# 187 (1997)                    0.027398                 41

# %%
corr_starwars[corr_starwars['number of ratings']>100].sort_values('correlation',ascending=False).head()
# Out:
#                                                     correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     number of ratings
# title
# Star Wars (1977)                                                  584
# Empire Strikes Back, The (1980)                                   368
# Return of the Jedi (1983)                                         507
# Raiders of the Lost Ark (1981)                                    420
# Austin Powers: International Man of Mystery (1997)                130
